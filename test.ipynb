# %%
import src as dp

# %%
# dp.Graph.from_csv("graphs/production_right.csv").draw()

# %%
dp.Graph.from_obj("graphs/graph.obj").draw()
# Out:
# {1: [np.float64(-0.37758993277006747), np.float64(0.27645740875994856)],
#  2: [np.float64(0.5865720474008167), np.float64(0.7235425912400523)],
#  3: [np.float64(-0.2089821146307492), np.float64(-1.0)]}

# %%
G = dp.Graph.from_csv("graphs/initial2_graph.csv")
L = dp.Graph.from_csv("graphs/production_left.csv")
R = dp.Graph.from_csv("graphs/production_right.csv", pos_like=L.pos)

# %%
G.draw()
# Out:
# {1: [np.float64(-0.005733579846116291), np.float64(0.20944698594195432)],
#  2: [np.float64(0.49503009247631186), np.float64(-0.6060218221563501)],
#  3: [np.float64(-0.5136686872896403), np.float64(0.9999999999999999)],
#  4: [np.float64(0.024372174659445016), np.float64(-0.603425163785604)]}

# %%
def load_mappings(filename):
    with open(filename, 'r') as f:
        mapping_line = f.readline().strip()
        return [int(x.strip()) for x in mapping_line.split(',') if x.strip()]

# %%
mapping = load_mappings("graphs/mapping.csv")

# %%
production = dp.Production(L, R)
result_graph = production.apply(G, mapping)

# %%
production.draw()

# %%
result_graph.draw()
# Out:
# {1: [np.float64(-0.005733579846116291), np.float64(0.20944698594195432)],
#  2: [np.float64(0.49503009247631186), np.float64(-0.6060218221563501)],
#  3: [np.float64(-0.5136686872896403), np.float64(0.9999999999999999)],
#  4: [np.float64(0.024372174659445016), np.float64(-0.603425163785604)],
#  5: [np.float64(-3.860143349935182), np.float64(-1.2855953818854648)]}
