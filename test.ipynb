# %%
import src as dp

# %%
# dp.Graph.from_csv("graphs/production_right.csv").draw()

# %%
dp.Graph.from_obj("graphs/graphs_obj/graph.obj").draw()
# Out:
# {1: [np.float64(-0.3934074851737359), np.float64(0.39331954281006504)],
#  2: [np.float64(-0.6065925148262641), np.float64(-0.87864081419834)],
#  3: [np.float64(1.0), np.float64(0.48532127138827497)]}

# %%
G = dp.Graph.from_csv("graphs/graphs_csv/initial2_graph.csv")
L = dp.Graph.from_csv("graphs/graphs_csv/production_left.csv")
R = dp.Graph.from_csv("graphs/graphs_csv/production_right.csv", pos_like=L.pos)

# %%
G.draw()
# Out:
# {1: [np.float64(0.22607532314304446), np.float64(0.1304969523811305)],
#  2: [np.float64(-0.55639255242546), np.float64(-0.7362317892248398)],
#  3: [np.float64(1.0), np.float64(0.994996219196777)],
#  4: [np.float64(-0.6696827707175844), np.float64(-0.3892613823530678)]}

# %%
def load_mappings(filename):
    with open(filename, 'r') as f:
        mapping_line = f.readline().strip()
        return [int(x.strip()) for x in mapping_line.split(',') if x.strip()]

# %%
mapping = load_mappings("graphs/mapping.csv")

# %%
production = dp.Production(L, R)
result_graph = production.apply(G, mapping, transform_positions=True)

# %%
production.draw()
# Out:
# /Users/emiliasarna/Pliki/STUDIA/semestr5/transformacje_grafowe/double-push-out-visualisation/src/production.py:197: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
result_graph.draw()
# Out:
# {1: [np.float64(0.22607532314304446), np.float64(0.1304969523811305)],
#  2: [np.float64(-0.55639255242546), np.float64(-0.7362317892248398)],
#  3: [np.float64(1.0), np.float64(0.994996219196777)],
#  4: [np.float64(-0.6696827707175844), np.float64(-0.3892613823530678)],
#  5: [np.float64(0.3317668625979097), np.float64(-0.26668477057626877)]}
